# %% [markdown]
# # Prepare Downloaded IPL Data
#
# Data Source: https://cricsheet.org/downloads/
#
# Data Information: https://cricsheet.org/format/csv_ashwin/#introduction-to-the-quot-ashwin-quot-csv-format

# %%
# Import required packages
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Prepare IPL Match Info data

# %%
# Function to store file temporary
def get_files(path):
    for file in os.listdir(path):
        if os.path.isfile(os.path.join(path, file)):
            yield file

# %%
# Get the list of file names from directory
folder_name = 'ipl_csv2'
list_files = []
for file in get_files(folder_name):
    list_files.append(file)


# Get the _info files from the from directory
list_info_files = []
list_match_id = []
for ind, file in enumerate(list_files):
    if file[-9:] == '_info.csv':
        list_info_files.append(file)
        list_match_id.append(file[:-9])

# %%
def get_match_info_data(list_filenames, dir_name, list_id):
    match_info_list_dict = []
    for i in range(len(list_filenames)):
        dict = {'match_id': list_id[i]}
        df = pd.read_csv(str(dir_name)+'/'+str(list_filenames[i]), on_bad_lines='skip')
        col = list(df.iloc[1:,0])
        data = list(df.iloc[1:,1])
        for i in range(len(col)):
            if col[i] in dict:
                dict[col[i]+'_1'] = data[i]
            else:
                dict[col[i]] = data[i]
#         dict = {key_cols[ind]: data[ind] for ind in range(len(key_cols))}
        match_info_list_dict.append(dict)
    return match_info_list_dict

# %%
# Export data from csv and save in dataframe
match_info_dict = get_match_info_data(list_info_files, folder_name, list_match_id)
df = pd.DataFrame(match_info_dict)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   match_id         950 non-null    object
#  1   team             950 non-null    object
#  2   team_1           950 non-null    object
#  3   gender           950 non-null    object
#  4   season           950 non-null    object
#  5   date             950 non-null    object
#  6   event            950 non-null    object
#  7   match_number     892 non-null    object
#  8   venue            950 non-null    object
#  9   city             899 non-null    object
#  10  toss_winner      950 non-null    object
#  11  toss_decision    950 non-null    object
#  12  player_of_match  946 non-null    object
#  13  umpire           950 non-null    object
#  14  umpire_1         950 non-null    object
#  15  reserve_umpire   926 non-null    object
#  16  tv_umpire        947 non-null    object
#  17  match_referee    950 non-null    object
#  18  winner           932 non-null    object
#  19  winner_wickets   509 non-null    object
#  20  winner_runs      423 non-null    object
#  21  outcome          18 non-null     object
#  22  eliminator       14 non-null     object
#  23  method           19 non-null     object
#  24  date_1           2 non-null      object
# dtypes: object(25)
# memory usage: 185.7+ KB

# %%
df.head()
# Out:
#   match_id                         team                       team_1 gender  \
# 0   729305             Rajasthan Royals  Royal Challengers Bangalore   male
# 1   392199  Royal Challengers Bangalore        Kolkata Knight Riders   male
# 2   392198             Delhi Daredevils             Rajasthan Royals   male
# 3   734021          Sunrisers Hyderabad  Royal Challengers Bangalore   male
# 4   336010        Kolkata Knight Riders  Royal Challengers Bangalore   male
#
#     season        date                  event match_number  \
# 0     2014  2014/04/26  Indian Premier League           14
# 1     2009  2009/04/29  Indian Premier League           19
# 2     2009  2009/04/28  Indian Premier League           18
# 3     2014  2014/05/20  Indian Premier League           46
# 4  2007/08  2008/05/08  Indian Premier League           29
#
#                                        venue       city  ...  reserve_umpire  \
# 0                       Sheikh Zayed Stadium  Abu Dhabi  ...       K Srinath
# 1                                  Kingsmead     Durban  ...     ZTA Ndamane
# 2                            SuperSport Park  Centurion  ...       JD Cloete
# 3  Rajiv Gandhi International Stadium, Uppal  Hyderabad  ...  A Nand Kishore
# 4                               Eden Gardens    Kolkata  ...             NaN
#
#         tv_umpire match_referee                       winner winner_wickets  \
# 0  RK Illingworth    AJ Pycroft             Rajasthan Royals              6
# 1      SL Shastri   D Govindjee  Royal Challengers Bangalore              5
# 2       DJ Harper     J Srinath             Rajasthan Royals              5
# 3       CK Nandan  RS Madugalle          Sunrisers Hyderabad              7
# 4     BR Doctrove   FM Engineer        Kolkata Knight Riders            NaN
#
#   winner_runs outcome eliminator method date_1
# 0         NaN     NaN        NaN    NaN    NaN
# 1         NaN     NaN        NaN    NaN    NaN
# 2         NaN     NaN        NaN    NaN    NaN
# 3         NaN     NaN        NaN    NaN    NaN
# 4           5     NaN        NaN    NaN    NaN
#
# [5 rows x 25 columns]

# %%
# Update column names
df.rename(columns={'team': 'team1', 'team_1': 'team2', 'umpire':'umpire1', 'umpire_1':'umpire2'}, inplace=True)

# Create new column based on existing columns
df.loc[df['winner_wickets'].notnull(), 'result_type'] = 'chased'
df.loc[df['winner_runs'].notnull(), 'result_type'] = 'defended'
df.loc[df['outcome'] == 'tie', 'result_type'] = 'tie'
df.loc[df['outcome'] == 'no result', 'result_type'] = 'no result'

df.loc[df['winner_wickets'].isnull(), 'winner_wickets'] = 0
df.loc[df['winner_runs'].isnull(), 'winner_runs'] = 0
df['results'] = df['winner_wickets'].astype(int) + df['winner_runs'].astype(int)

# Update data type
df['date'] = pd.to_datetime(df.date)
df['match_id'] = df.match_id.astype(int)
df['winner_wickets'] = df.winner_wickets.astype(int)
df['winner_runs'] = df.winner_runs.astype(int)

# %%
columns = ['match_id', 'season', 'date', 'city', 'venue', 'team1', 'team2',
           'toss_winner', 'toss_decision', 'player_of_match', 
           'winner', 'winner_wickets', 'winner_runs', 'outcome', 'result_type', 'results', 
           'gender', 'event', 'match_number', 'umpire1', 'umpire2', 'reserve_umpire', 
           'tv_umpire', 'match_referee', 'eliminator', 'method', 'date_1']

# Save in df as ordered columns
df_final = df[columns]
df_final = df_final.sort_values(by='match_id', ascending=True).reset_index(drop=True)

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 27 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   match_id         950 non-null    int64
#  1   season           950 non-null    object
#  2   date             950 non-null    datetime64[ns]
#  3   city             899 non-null    object
#  4   venue            950 non-null    object
#  5   team1            950 non-null    object
#  6   team2            950 non-null    object
#  7   toss_winner      950 non-null    object
#  8   toss_decision    950 non-null    object
#  9   player_of_match  946 non-null    object
#  10  winner           932 non-null    object
#  11  winner_wickets   950 non-null    int64
#  12  winner_runs      950 non-null    int64
#  13  outcome          18 non-null     object
#  14  result_type      950 non-null    object
#  15  results          950 non-null    int64
#  16  gender           950 non-null    object
#  17  event            950 non-null    object
#  18  match_number     892 non-null    object
#  19  umpire1          950 non-null    object
#  20  umpire2          950 non-null    object
#  21  reserve_umpire   926 non-null    object
#  22  tv_umpire        947 non-null    object
#  23  match_referee    950 non-null    object
#  24  eliminator       14 non-null     object
#  25  method           19 non-null     object
#  26  date_1           2 non-null      object
# dtypes: datetime64[ns](1), int64(4), object(22)
# memory usage: 200.5+ KB

# %%
df_final.head()
# Out:
#    match_id   season       date        city  \
# 0    335982  2007/08 2008-04-18   Bangalore
# 1    335983  2007/08 2008-04-19  Chandigarh
# 2    335984  2007/08 2008-04-19       Delhi
# 3    335985  2007/08 2008-04-20      Mumbai
# 4    335986  2007/08 2008-04-20     Kolkata
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1          Chennai Super Kings          Chennai Super Kings           bat
# 2             Rajasthan Royals             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4              Deccan Chargers              Deccan Chargers           bat
#
#   player_of_match  ...                  event  match_number    umpire1  \
# 0     BB McCullum  ...  Indian Premier League             1  Asad Rauf
# 1      MEK Hussey  ...  Indian Premier League             2  MR Benson
# 2     MF Maharoof  ...  Indian Premier League             3  Aleem Dar
# 3      MV Boucher  ...  Indian Premier League             5   SJ Davis
# 4       DJ Hussey  ...  Indian Premier League             4  BF Bowden
#
#           umpire2 reserve_umpire       tv_umpire      match_referee  \
# 0     RE Koertzen    VN Kulkarni       AM Saheba          J Srinath
# 1      SL Shastri    MSS Ranawat       RB Tiffin  S Venkataraghavan
# 2  GA Pratapkumar            NaN       IL Howell       GR Viswanath
# 3       DJ Harper    SN Bandekar  AV Jayaprakash          J Srinath
# 4     K Hariharan        F Gomes       Asad Rauf        FM Engineer
#
#   eliminator method date_1
# 0        NaN    NaN    NaN
# 1        NaN    NaN    NaN
# 2        NaN    NaN    NaN
# 3        NaN    NaN    NaN
# 4        NaN    NaN    NaN
#
# [5 rows x 27 columns]

# %%
# Save file to current directory
# df_final.to_csv(r'/Users/robot/MachineLearning/Kaggle/cricket/ipl_match_info_data.csv', index=False)
# os.getcwd()

# %% [markdown]
# # IPL Ball-by-Ball data

# %%
all_match = pd.read_csv('ipl_csv2/all_matches.csv', low_memory=False)
all_match.sort_values(by='match_id', ascending=True).reset_index(drop=True)
all_match.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225954 entries, 0 to 225953
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   match_id                225954 non-null  int64
#  1   season                  225954 non-null  object
#  2   start_date              225954 non-null  object
#  3   venue                   225954 non-null  object
#  4   innings                 225954 non-null  int64
#  5   ball                    225954 non-null  float64
#  6   batting_team            225954 non-null  object
#  7   bowling_team            225954 non-null  object
#  8   striker                 225954 non-null  object
#  9   non_striker             225954 non-null  object
#  10  bowler                  225954 non-null  object
#  11  runs_off_bat            225954 non-null  int64
#  12  extras                  225954 non-null  int64
#  13  wides                   7026 non-null    float64
#  14  noballs                 918 non-null     float64
#  15  byes                    583 non-null     float64
#  16  legbyes                 3531 non-null    float64
#  17  penalty                 2 non-null       float64
#  18  wicket_type             11151 non-null   object
#  19  player_dismissed        11151 non-null   object
#  20  other_wicket_type       0 non-null       float64
#  21  other_player_dismissed  0 non-null       float64
# dtypes: float64(8), int64(4), object(10)
# memory usage: 37.9+ MB

# %%
all_match.head()
# Out:
#    match_id   season  start_date                  venue  innings  ball  \
# 0    335982  2007/08  2008-04-18  M Chinnaswamy Stadium        1   0.1
# 1    335982  2007/08  2008-04-18  M Chinnaswamy Stadium        1   0.2
# 2    335982  2007/08  2008-04-18  M Chinnaswamy Stadium        1   0.3
# 3    335982  2007/08  2008-04-18  M Chinnaswamy Stadium        1   0.4
# 4    335982  2007/08  2008-04-18  M Chinnaswamy Stadium        1   0.5
#
#             batting_team                 bowling_team      striker  \
# 0  Kolkata Knight Riders  Royal Challengers Bangalore   SC Ganguly
# 1  Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 2  Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 3  Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 4  Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
#
#    non_striker  ... extras  wides  noballs  byes  legbyes  penalty  \
# 0  BB McCullum  ...      1    NaN      NaN   NaN      1.0      NaN
# 1   SC Ganguly  ...      0    NaN      NaN   NaN      NaN      NaN
# 2   SC Ganguly  ...      1    1.0      NaN   NaN      NaN      NaN
# 3   SC Ganguly  ...      0    NaN      NaN   NaN      NaN      NaN
# 4   SC Ganguly  ...      0    NaN      NaN   NaN      NaN      NaN
#
#    wicket_type  player_dismissed other_wicket_type other_player_dismissed
# 0          NaN               NaN               NaN                    NaN
# 1          NaN               NaN               NaN                    NaN
# 2          NaN               NaN               NaN                    NaN
# 3          NaN               NaN               NaN                    NaN
# 4          NaN               NaN               NaN                    NaN
#
# [5 rows x 22 columns]

# %%
# Save file to current directory
# all_match.to_csv(r'/Users/robot/MachineLearning/Kaggle/cricket/ipl_match_ball_by_ball_data.csv', index=False)
# os.getcwd()
# Out:
# '/Users/robot/MachineLearning/Kaggle/cricket'
